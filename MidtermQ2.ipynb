# %%
import pandas as pd

df = pd.read_csv('C:/Users/chane/Desktop/amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   08/22/19  112-6174064-0660245       MasterCard - 9359  Amazon.com
# 1   08/22/19  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 2   08/22/19  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 3   08/30/19  112-1794810-4484241       MasterCard - 9359  Amazon.com
# 4   09/06/19  112-1761552-3026661       MasterCard - 9359  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN        jnhsu_78@gwu.edu      08/26/19
# 1                    NaN        jnhsu_78@gwu.edu      08/26/19
# 2                    NaN        jnhsu_78@gwu.edu      08/27/19
# 3                    NaN        jnhsu_78@gwu.edu      09/08/19
# 4                    NaN        jnhsu_78@gwu.edu      09/09/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0          JINGNING HSU              2100 I ST NW                        NaN
# ...

# %%
df.shape
# Out:
# (99, 23)

# %%
df = df.fillna(value=0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-08-22  112-6174064-0660245       MasterCard - 9359  Amazon.com
# 1 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 2 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 3 2019-08-30  112-1794810-4484241       MasterCard - 9359  Amazon.com
# 4 2019-09-06  112-1761552-3026661       MasterCard - 9359  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        jnhsu_78@gwu.edu      08/26/19
# 1                    0.0        jnhsu_78@gwu.edu      08/26/19
# 2                    0.0        jnhsu_78@gwu.edu      08/27/19
# 3                    0.0        jnhsu_78@gwu.edu      09/08/19
# 4                    0.0        jnhsu_78@gwu.edu      09/09/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0          JINGNING HSU              2100 I ST NW                        0.0
# ...

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-08-22  112-6174064-0660245       MasterCard - 9359  Amazon.com
# 1 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 2 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 3 2019-08-30  112-1794810-4484241       MasterCard - 9359  Amazon.com
# 4 2019-09-06  112-1761552-3026661       MasterCard - 9359  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        jnhsu_78@gwu.edu      08/26/19
# 1                    0.0        jnhsu_78@gwu.edu      08/26/19
# 2                    0.0        jnhsu_78@gwu.edu      08/27/19
# 3                    0.0        jnhsu_78@gwu.edu      09/08/19
# 4                    0.0        jnhsu_78@gwu.edu      09/09/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0          JINGNING HSU              2100 I ST NW                        0.0
# ...

# %%
data = {
    "Sum":{"Amount($)":df["Total Charged"].sum()},
    "Mean":{"Amount($)":df["Total Charged"].mean()},
    "Median":{"Amount($)":df["Total Charged"].median()},
    "Max":{"Amount($)":df["Total Charged"].max()},
    "Min":{"Amount($)":df["Total Charged"].min()}
}

obj = pd.DataFrame(data)
print(obj)
# Out:
#                Sum      Mean  Median     Max  Min
# Amount($)  3110.38  31.41798   24.02  136.74  0.0

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-08-22  112-6174064-0660245       MasterCard - 9359  Amazon.com
# 1 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 2 2019-08-22  112-6137686-4625862       MasterCard - 9359  Amazon.com
# 3 2019-08-30  112-1794810-4484241       MasterCard - 9359  Amazon.com
# 4 2019-09-06  112-1761552-3026661       MasterCard - 9359  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        jnhsu_78@gwu.edu      08/26/19
# 1                    0.0        jnhsu_78@gwu.edu      08/26/19
# 2                    0.0        jnhsu_78@gwu.edu      08/27/19
# 3                    0.0        jnhsu_78@gwu.edu      09/08/19
# 4                    0.0        jnhsu_78@gwu.edu      09/09/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0          JINGNING HSU              2100 I ST NW                        0.0
# ...

# %%
# %matplotlib inline

# %%
daily_orders = df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2019-08-22    87.18
# 2019-08-30    44.29
# 2019-09-06    57.30
# 2019-09-08    36.03
# 2019-09-11    45.07
# Name: Total Charged, dtype: float64

# %%
monthly_orders = df.groupby(pd.Grouper(key='Order Date', axis=0, 
                      freq='M')).sum()["Total Charged"]
monthly_orders.head()
# Out:
# Order Date
# 2019-08-31    131.47
# 2019-09-30    610.16
# 2019-10-31    306.16
# 2019-11-30     22.23
# 2019-12-31      0.00
# Freq: M, Name: Total Charged, dtype: float64

# %%
monthly_orders.plot.bar(ylabel='Total Charged',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Total Charged'>
